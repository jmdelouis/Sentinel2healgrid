# %%
import healpy as hp
import xarray as xr
import xdggs
import fsspec
import sparse

# %%
fs = fsspec.filesystem("http")
dtotal=xr.open_zarr("test.zarr").pipe(xdggs.decode)
dtotal
# Out:
# /tmp/ipykernel_251182/455061550.py:2: SerializationWarning: Unable to decode time axis into full numpy.datetime64[ns] objects, continuing using cftime.datetime objects instead, reason: dates out of range. To silence this warning use a coarser resolution 'time_unit' or specify 'use_cftime=True'.
#   dtotal=xr.open_zarr("test.zarr").pipe(xdggs.decode)
# /tmp/ipykernel_251182/455061550.py:2: SerializationWarning: Unable to decode time axis into full numpy.datetime64[ns] objects, continuing using cftime.datetime objects instead, reason: dates out of range. To silence this warning use a coarser resolution 'time_unit' or specify 'use_cftime=True'.
#   dtotal=xr.open_zarr("test.zarr").pipe(xdggs.decode)
# <xarray.Dataset> Size: 833MB
# Dimensions:    (time: 31, bands: 11, cells: 304537)
# Coordinates:
#   * bands      (bands) <U3 132B 'b01' 'b02' 'b03' 'b04' ... 'b11' 'b12' 'b8a'
#   * cell_ids   (cells) int64 2MB dask.array<chunksize=(304537,), meta=np.ndarray>
# ...

# %%
dtotal.Sentinel2.compute().dggs.explore(alpha=0.8,cmap='coolwarm')
